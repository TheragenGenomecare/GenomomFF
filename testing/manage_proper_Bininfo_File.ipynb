# %%
import pandas as pd

# %%
rgc_bin = pd.read_csv("rgcbininfo_117.csv")
rgc_bin.head()
# Out:
#    Unnamed: 0  \
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#
#   GC1804N1902_R1_V1_IonXpress_095.Fastq.sam.bam.sort.bam.rmdup.bam.sam_rgc.csv  \
# 0  GC1804N1903_R1_V1_IonXpress_096.Fastq.sam.bam....
# 1  GC1804N1904_R1_V1_IonXpress_049.Fastq.sam.bam....
# 2  GC1804N1905_R1_V1_IonXpress_050.Fastq.sam.bam....
# 3  GC1804N1906_R1_V1_IonXpress_051.Fastq.sam.bam....
# 4  GC1804N1909_R1_V1_IonXpress_056.Fastq.sam.bam....
#
#    X7.492877787
# 0      5.373462
# 1      7.678283
# 2      4.542663
# 3     13.270487
# 4     22.628155

# %%
rgc_bin = rgc_bin.iloc[:,1:]

# %%
rgc_bin.to_csv("rgcbininfo_117.csv",index = None)

# %%
test = pd.read_csv("rgcbininfo_117.csv")
test.head()
# Out:
#   GC1804N1902_R1_V1_IonXpress_095.Fastq.sam.bam.sort.bam.rmdup.bam.sam_rgc.csv  \
# 0  GC1804N1903_R1_V1_IonXpress_096.Fastq.sam.bam....
# 1  GC1804N1904_R1_V1_IonXpress_049.Fastq.sam.bam....
# 2  GC1804N1905_R1_V1_IonXpress_050.Fastq.sam.bam....
# 3  GC1804N1906_R1_V1_IonXpress_051.Fastq.sam.bam....
# 4  GC1804N1909_R1_V1_IonXpress_056.Fastq.sam.bam....
#
#    X7.492877787
# 0      5.373462
# 1      7.678283
# 2      4.542663
# 3     13.270487
# 4     22.628155

# %%
df = pd.read_csv("srlbininfo_117",sep= "\t")

# %%
df.to_csv("srlbininfo_117.csv",sep=",",index=None)

# %%
df = pd.read_csv("srlbininfo_117.csv")
df
# Out:
#     GC1804N1902_R1_V1_IonXpress_095.Fastq.sam.bam.sort.bam.rmdup.bam.sam.srl  \
# 0    GC1804N1903_R1_V1_IonXpress_096.Fastq.sam.bam....
# 1    GC1804N1904_R1_V1_IonXpress_049.Fastq.sam.bam....
# 2    GC1804N1905_R1_V1_IonXpress_050.Fastq.sam.bam....
# 3    GC1804N1906_R1_V1_IonXpress_051.Fastq.sam.bam....
# 4    GC1804N1909_R1_V1_IonXpress_056.Fastq.sam.bam....
# ..                                                 ...
# 111  GC1804N2129_R1_V1_IonXpress_066.Fastq.sam.bam....
# 112  GC1804N2134_R1_V1_IonXpress_071.Fastq.sam.bam....
# 113  GC1804N2136_R1_V1_IonXpress_073.Fastq.sam.bam....
# 114  GC1804N2137_R1_V1_IonXpress_074.Fastq.sam.bam....
# 115  GC1804N2139_R1_V1_IonXpress_076.Fastq.sam.bam....
#
#      7.492877787
# 0       5.373462
# 1       7.678283
# 2       4.542663
# 3      13.270487
# 4      22.628155
# ..           ...
# 111     7.974148
# 112    11.050443
# 113    17.954175
# 114    11.363165
# 115     6.579608
#
# [116 rows x 2 columns]
